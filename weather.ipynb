# %%
import numpy as np
import pandas as pd
import pickle
import datetime

# %%
kenner = pd.read_pickle('kenner_scrape.pkl')

# %%
kenner
# Out:
#                 ID max_temp_deg_f avg_temp_deg_f min_temp_deg_f  \
# 0      KMSY_2008-1             54           49.1             41
# 1      KMSY_2008-1             43           37.9             33
# 2      KMSY_2008-1             41           34.9             28
# 3      KMSY_2008-1             62           51.5             39
# 4      KMSY_2008-1             71           61.4             55
# ...            ...            ...            ...            ...
# 4741  KMSY_2020-12             67           54.5             40
# 4742  KMSY_2020-12             72           60.1             49
# 4743  KMSY_2020-12             72           61.5             50
# 4744  KMSY_2020-12             77           68.5             61
# 4745  KMSY_2020-12             76           71.0             64
#
#      max_dew_point_deg_f avg_dew_point_deg_f min_dew_point_deg_f  \
# 0                     44                26.4                  18
# ...

# %%
kenner = kenner[['ID', 'avg_temp_deg_f', 'avg_dew_humidity_pct', 'avg_wind_speed_mph', 'tot_precipitation_in']]
kenner
# Out:
#                 ID avg_temp_deg_f avg_dew_humidity_pct avg_wind_speed_mph  \
# 0      KMSY_2008-1           49.1                 42.7               15.3
# 1      KMSY_2008-1           37.9                 39.8               17.8
# 2      KMSY_2008-1           34.9                 52.3                8.5
# 3      KMSY_2008-1           51.5                 69.5               10.2
# 4      KMSY_2008-1           61.4                 80.5               10.7
# ...            ...            ...                  ...                ...
# 4741  KMSY_2020-12           54.5                 69.0                5.7
# 4742  KMSY_2020-12           60.1                 69.9                5.2
# 4743  KMSY_2020-12           61.5                 76.1                8.6
# 4744  KMSY_2020-12           68.5                 74.0               12.6
# 4745  KMSY_2020-12           71.0                 83.7               15.4
#
#      tot_precipitation_in
# 0                    0.00
# ...

# %%
kenner[['avg_temp_deg_f', 'avg_dew_humidity_pct', 'avg_wind_speed_mph', 'tot_precipitation_in']] = kenner[['avg_temp_deg_f', 'avg_dew_humidity_pct', 'avg_wind_speed_mph', 'tot_precipitation_in']].astype(float)
# Out:
# /Users/dunleavyjason/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
kenner[["city", "yyyy-m"]] = kenner.ID.str.split('_', expand = True)
# Out:
# /Users/dunleavyjason/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
del kenner["ID"]

# %%
kenner.groupby(["city", "yyyy-m"]).aggregate(np.average)
# Out:
#               avg_temp_deg_f  avg_dew_humidity_pct  avg_wind_speed_mph  \
# city yyyy-m
# KMSY 2008-1        52.841935             74.177419           10.264516
#      2008-10       70.283871             68.964516            7.596774
#      2008-11       60.713333             69.950000            7.443333
#      2008-12       58.577419             75.477419            9.112903
#      2008-2        59.306897             74.062069            9.289655
# ...                      ...                   ...                 ...
#      2020-5        77.690323             66.545161            8.480645
#      2020-6        83.386667             69.083333            7.443333
#      2020-7        84.764516             74.567742            7.200000
#      2020-8        83.658065             72.606452            6.870968
#      2020-9        79.610000             73.960000            8.670000
#
#               tot_precipitation_in
# city yyyy-m
# KMSY 2008-1               0.000000
# ...

# %%
group_by
